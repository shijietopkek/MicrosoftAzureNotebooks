# %%
'''
Guess the number game.
The computer selects a random number between 1 and 100.
The user keeps guessing which number the computer has chosen
until they get it right.
The computer responds 'bingo!' or 'too high' or 'too low' after
each guess.
After the user has guessed the number correctly the computer output
how many attempts it has made.
'''
import random
random_num = random.randint(1,100)
try:
    attempt = 0
    while True:
        user = int(input("Enter a number (1-100): "))
        if user != random_num:
            if user < random_num:
                print("Too low!")
            else:
                print("Too high!")
            attempt += 1
        else:
            print("Bingo!")
            attempt+=1
            print("No. of attempt: {}".format(attempt))
            break
except (TypeError, ValueError, EOFError) as err:
    print("Invalid input!")
# Out:
# Enter a number (1-100): 30
# Too low!
# Enter a number (1-100): 60
# Too high!
# Enter a number (1-100): 50
# Too high!
# Enter a number (1-100): 40
# Too high!
# Enter a number (1-100): 35
# Too high!
# Enter a number (1-100): 32
# Too low!
# Enter a number (1-100): 33
# Bingo!
# No. of attempt: 7

# %%
'''
Reverse the above game. You think of a number. Get the
computer to guess a number and you respond with too high(H),
too low(L) or bingo!(B). Make sure the computer has a game
plan - don't just let it guess at random!
'''
import random
first= random.randint(1,100)
valid = ['H','L','B']
low = 1
high = 100
while True:
    print(first)
    user = input("Enter your response: ")
    if user not in valid:
        print("Invalid input!")
        break;
    else:
        if user=='L':
            low = first + 1
            first = random.randint(low,high)
        elif user == 'H':
            high = first - 1
            first = random.randint(low,high)
        else:
            print("Bingo!")
            break;
        
    
# number = 45
# Out:
# 8
# Enter your response: L
# 47
# Enter your response: H
# 24
# Enter your response: L
# 27
# Enter your response: L
# 37
# Enter your response: L
# 41
# Enter your response: L
# 45
# Enter your response: B
# Bingo!

# %%
'''
Write a function that will convert a mark into a grade.
The function will return 'A', 'B', 'C', 'D', 'E', 'S' or 'U'.
The function will require a parameter mark.
The formula is >=70% â> 'A', >=60% â>'B', >=55% â> 'C',
>=50% â> 'D', >=45% â>'E', >=40% â> 'S', <40% â> 'U'.
Assume the maximum mark is 100.
Having written the function we want to use it three times.
Write a program with the function that allows the user to enter
two module marks and displays the grade. It then computes the
average and displays the overall grade. E.g.

Enter Module 1 mark: 68
Enter Module 2 mark: 57
Result
Module 1: B
Module 2: C
Overall: B 
'''
def grade(mark):
    if mark < 40:
        return 'U'
    elif mark < 45:
        return 'S'
    elif mark < 50:
        return 'E'
    elif mark < 55:
        return 'D'
    elif mark < 60:
        return 'C'
    elif mark < 70:
        return 'B'
    else:
        return 'A'

first = int(input("Enter Module 1 mark: "))
second = int(input("Enter Module 2 mark: "))
avg = (first + second)/2
print("Result.")
print("Module 1: {}".format(grade(first)))
print("Module 2: {}".format(grade(second)))
print("Overall: {}".format(grade(avg)))
# Out:
# Enter Module 1 mark: 43
# Enter Module 2 mark: 56
# Result.
# Module 1: S
# Module 2: C
# Overall: E

# %%
'''
For the above problem, allow a maximum mark other than 100.
This will require the user to enter both the mark and maximum possible for that module.
The function will also require the maximum mark in order to calculate
the grade so another parameter will be needed. 
'''
def grade(mark,max_mark):
    weight = mark/max_mark
    if weight < 0.40:
        return 'U'
    elif weight < 0.45:
        return 'S'
    elif weight < 0.50:
        return 'E'
    elif weight < 0.55:
        return 'D'
    elif weight < 0.60:
        return 'C'
    elif weight < 0.70:
        return 'B'
    else:
        return 'A'
max_mark = int(input("Enter maximum mark: "))
first = int(input("Enter Module 1 mark: "))
second = int(input("Enter Module 2 mark: "))
avg = (first + second)/2
print("Result.")
print("Module 1: {}".format(grade(first,max_mark)))
print("Module 2: {}".format(grade(second,max_mark)))
print("Overall: {}".format(grade(avg,max_mark)))
# Out:
# Enter maximum mark: 200
# Enter Module 1 mark: 100
# Enter Module 2 mark: 150
# Result.
# Module 1: D
# Module 2: A
# Overall: B

# %%
'''
Write a procedure draw_stars that will draw a sequence of spaces followed by a sequence of stars.
It should accept two parameters - the number of spaces and the number of stars. E.g

draw_stars(3,5) would produce
___***** ( _ indicates a space)

Use your procedure to draw

  ***
  ***
   *
  ***
*******
  ***
  * *
 ** ** 
'''
def draw_stars(x,y):
    print((" "*x + "*" * y), end='')

#main
draw_stars(2,3)
print()
draw_stars(2,3)
print()
draw_stars(3,1)
print()
draw_stars(2,3)
print()
draw_stars(0,7)
print()
draw_stars(2,3)
print()
draw_stars(2,1)
draw_stars(1,1)
print()
draw_stars(1,2)
draw_stars(1,2)
print()
# Out:
#   ***
#   ***
#    *
#   ***
# *******
#   ***
#   * *
#  ** **

# %%
'''
Write a program using the above draw_stars procedure that will draw a pyramid
whose base is a width specified by the user. E.g.

Enter base: 5
  *
 ***
*****

Assume base is an odd number. 
'''
def draw_stars(x,y):
    print((" "*x + "*" * y), end='')

#main
user = int(input("Enter base: "))
j = user//2+1
for i in range(j):
    draw_stars(j-1-i,i+(i+1)*(1))
    print()
# Out:
# Enter base: 11
#      *
#     ***
#    *****
#   *******
#  *********
# ***********

# %%
'''
Write a program to perform a basic encryption and decryption on text.
This algorithm works by moving letters along by an offset. 
If the offset is 2 then b â> d, h â> j, etc.
Write two functions - encrypt and decrypt. Both will return a string.
The user selects whether to encrypt or decrypt.
The user enters sentence to encrypt and the offset.
The program responds with the encrypted or decrypted version. 
'''

def encryption(sentence):
    new_str = ''
    for i in sentence:
        new_ascii = ord(i)+2
        if new_ascii > 122:
            new_ascii = 96 + (new_ascii)%122
        new_char = chr(new_ascii)
        new_str += new_char 
    return new_str
print(encryption("helloworld"))
# Out:
# jgnnqyqtnf

# %%
'''
The above algorithm is actually easy to crack. A much better algorithm 
would be one that has a different offset for every letter. 
We can do this using the random number generator - because it generates 
the same sequence of random numbers from a 'seed' position. As long as
sender and receiver agree where to 'seed' (this will be the encryption
key) they can both work out the same offsets. 

Algorithm for encrypt function

function Encrypt(text, key)
  Randomize(key)
  For each letter in text
    Get its ascii code
    Add random offset int(rnd()*10) to ascii code
    Turn this new ascii code back to a character
    Append character to ciphertext string
  Endfor
  return ciphertext
end
'''
from random import randint
def encrypt(text,key):
    def Randomize(key,pos):
        return (key+pos)%key
    new_str = ''
    for i in range(len(text)):
        new_ascii = ord(text[i])+Randomize(key,i)
        if new_ascii > 122:
            new_ascii = 96 + (new_ascii)%122
        new_char = chr(new_ascii)
        new_str += new_char 
    return new_str

print(encrypt("helloworld", 10))
# Out:
# hfnosbuytm

# %%
'''
For the above task, use a single function with an extra parameter to indicate
whether the text is being encrypted or decrypted rather than having two 
different functions.
'''
from random import randint
def encrypt(text,key,encrypt=True):
    def Randomize(key,pos):
        return (key+pos)%key
    if encrypt==True:     
        new_str = ''
        for i in range(len(text)):
            new_ascii = ord(text[i])+Randomize(key,i)
            if new_ascii > 122:
                new_ascii = 96 + (new_ascii)%122
            new_char = chr(new_ascii)
            new_str += new_char 
        return new_str
    else: #decrypt it
        new_str = ''
        for i in range(len(text)):
            new_ascii = ord(text[i])-Randomize(key,i)
            if new_ascii < 97:
                new_ascii = 122 - (96-new_ascii)%97
            new_char = chr(new_ascii)
            new_str += new_char 
        return new_str

#main
print(encrypt("helloworld",10))
print(encrypt("hfnosbuytm",10,False))
# Out:
# hfnosbuytm
# helloworld
